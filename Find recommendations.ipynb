# %%
import pandas as pd
import numpy as np

# %%
#Count how many lines our file contains
# !type "C:\Users\priyanka.roychoudhur\Desktop\DS\BooksRecommendation\goodreads_interactions.csv" | find /c /v ""
# Out:
# 228648343

# %%
#read a few (non-header) rows to look at how our data looks like:

test = pd.read_csv("goodreads_interactions.csv", nrows=4)

test
# Out:
#    user_id  book_id  is_read  rating  is_reviewed
# 0        0      948        1       5            0
# 1        0      947        1       5            1
# 2        0      946        1       5            0
# 3        0      945        1       5            0

# %%
#to avoid overloading the memory by loading the entire dataset, we read it line by line

with open("goodreads_interactions.csv") as f: #default is to read the file "r"
    line = f.readline()
    
line #one line from the csv file
# Out:
# 'user_id,book_id,is_read,rating,is_reviewed\n'

# %%
#I only need the user_id, book_id and rating from this dataset pertaining to users who have also read the same books as me

#Based on the search script
my_books = ["4408", "31147619", "29983711", "9401317", "9317691", "8153988", "20494944"]

# %%
#The books id in the goodreads list of books data and the interactions data are different so we need to map the ids across two datasets

# !type "C:\Users\priyanka.roychoudhur\Desktop\DS\BooksRecommendation\book_id_map.csv" | find /c /v ""
# Out:
# 2360651

# %%
# !dir goodreads_interactions.csv /O:E
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is C084-E4B0
#
#  Directory of C:\Users\priyanka.roychoudhur\desktop\DS\BooksRecommendation
#
# 12/12/2022  15:06     4,318,621,741 goodreads_interactions.csv
#                1 File(s)  4,318,621,741 bytes
#                0 Dir(s)  1,521,501,212,672 bytes free

# %%
#Look at what the mapping dataset looks like

mapping_csv = pd.read_csv("book_id_map.csv")
mapping_csv
# Out:
#          book_id_csv   book_id
# 0                  0  34684622
# 1                  1  34536488
# 2                  2  34017076
# 3                  3     71730
# 4                  4  30422361
# ...              ...       ...
# 2360645      2360645  19517100
# 2360646      2360646  18597299
# 2360647      2360647  18584882
# 2360648      2360648  18518801
# 2360649      2360649  18518607
#
# [2360650 rows x 2 columns]

# %%
#Read in the mapping data
mapping_data = {}

with open("book_id_map.csv", "r") as f:  #default is to read the file "r"
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",") # if we don't use strip then there is white sace in the end "\n"
        mapping_data[csv_id] = book_id #assigning keys and values

# %%
len(mapping_data)
# Out:
# 2360651

# %%
mapping_data["945"]
# Out:
# '45'

# %%
#First we would want to identify only those users who have something in common with us in terms of the books they have read. 
#We will create a list with only the above common users

common_users = [] 

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.strip().split(",") # _ indicate that part of a function result is being deliberately ignored
        
        try:
            rating = int(rating)
        except ValueError:
            continue
            
        book_id = mapping_data.get(csv_id) #use get as otherwise python throws a key error
        
        if book_id in my_books and rating >= 4:
            common_users.append(user_id)

# %%
#remove duplicates so we have unique users in our list

common_users_unique = list(set(common_users))
print(len(common_users))
print(len(common_users_unique))
# Out:
# 2046
# 2029

# %%
#Now we have identified the user ids of the users who have read the same books as in our book list, 
# we can get the rest of the information 

interactions = []

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in common_users_unique:
            book_id = mapping_data.get(csv_id)
            interactions.append([user_id, book_id, rating])

# %%
#Create our dataframe which now has a more manageable size

df = pd.DataFrame(interactions, columns =["user_id", "book_id", "rating"])

df.shape
# Out:
# (1530257, 3)

# %%
df.head()
# Out:
#   user_id  book_id rating
# 0     284   977284      3
# 1     284   890054      4
# 2     284   837153      3
# 3     284  1586480      4
# 4     284    41814      5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1530257 entries, 0 to 1530256
# Data columns (total 3 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   user_id  1530257 non-null  object
#  1   book_id  1530257 non-null  object
#  2   rating   1530257 non-null  object
# dtypes: object(3)
# memory usage: 35.0+ MB

# %%
#No missing values 
#Convert rating data to numeric

df["rating"] = df["rating"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1530257 entries, 0 to 1530256
# Data columns (total 3 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   user_id  1530257 non-null  object
#  1   book_id  1530257 non-null  object
#  2   rating   1530257 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 35.0+ MB

# %%
#Look at what are the books id that are most read by the users
top_books = df["book_id"].value_counts().head(20)

# %%
top_books
# Out:
# 2767052     1092
# 29983711    1089
# 2657        1074
# 3           1048
# 4671        1028
# 18143977     977
# 38447        911
# 5470         907
# 77203        886
# 5107         886
# 22557272     882
# 15881        874
# 6148028      863
# 136251       856
# 7260188      849
# 2            827
# 1            817
# 19063        810
# 6            805
# 11870085     803
# Name: book_id, dtype: int64

# %%
#Bring up the details of these top 10 books from our goodreads dataset

top_books_index = top_books.index.values # get the top books id


books_titles = pd.read_json("books_titles.json")
books_titles["book_id"] = books_titles["book_id"].astype(str)

books_titles = books_titles.drop("cover_image", axis = 1)

books_recs = books_titles[books_titles["book_id"].isin(top_books_index)]

# %%
books_recs = books_recs.sort_values("ratings", ascending=False).reset_index(drop = True)

books_recs
# Out:
#      book_id                                              title  ratings  \
# 0    2767052            The Hunger Games (The Hunger Games, #1)  4899965
# 1          3  Harry Potter and the Sorcerer's Stone (Harry P...  4765497
# 2       2657                              To Kill a Mockingbird  3255518
# 3       4671                                   The Great Gatsby  2758812
# 4   11870085                             The Fault in Our Stars  2429317
# 5       5107                             The Catcher in the Rye  2086945
# 6       5470                                               1984  2023937
# 7    6148028               Catching Fire (The Hunger Games, #2)  1854746
# 8      77203                                    The Kite Runner  1848782
# 9      15881  Harry Potter and the Chamber of Secrets (Harry...  1821802
# 10         6  Harry Potter and the Goblet of Fire (Harry Pot...  1792561
# 11    136251  Harry Potter and the Deathly Hallows (Harry Po...  1784684
# 12         2  Harry Potter and the Order of the Phoenix (Har...  1766895
# 13   7260188                  Mockingjay (The Hunger Games, #3)  1743362
# 14         1  Harry Potter and the Half-Blood Prince (Harry ...  1713866
# 15     19063                                     The Book Thief  1193697
# 16  22557272                              The Girl on the Train  1076144
# 17     38447                                The Handmaid's Tale   648783
# 18  18143977                        All the Light We Cannot See   498685
# 19  29983711                                           Pachinko     8161
#
#                                                   url publication_year  \
# 0   https://www.goodreads.com/book/show/2767052-th...             2008
# 1   https://www.goodreads.com/book/show/3.Harry_Po...             1997
# 2   https://www.goodreads.com/book/show/2657.To_Ki...             2006
# 3   https://www.goodreads.com/book/show/4671.The_G...             2004
# 4   https://www.goodreads.com/book/show/11870085-t...             2012
# 5   https://www.goodreads.com/book/show/5107.The_C...             2001
# 6       https://www.goodreads.com/book/show/5470.1984             1950
# 7   https://www.goodreads.com/book/show/6148028-ca...             2009
# 8   https://www.goodreads.com/book/show/77203.The_...             2004
# 9   https://www.goodreads.com/book/show/15881.Harr...             1999
# 10  https://www.goodreads.com/book/show/6.Harry_Po...             2002
# 11  https://www.goodreads.com/book/show/136251.Har...             2007
# 12  https://www.goodreads.com/book/show/2.Harry_Po...             2004
# 13  https://www.goodreads.com/book/show/7260188-mo...             2010
# 14  https://www.goodreads.com/book/show/1.Harry_Po...             2006
# 15  https://www.goodreads.com/book/show/19063.The_...
# 16  https://www.goodreads.com/book/show/22557272-t...             2015
# 17  https://www.goodreads.com/book/show/38447.The_...             1998
# 18  https://www.goodreads.com/book/show/18143977-a...             2014
# 19  https://www.goodreads.com/book/show/29983711-p...             2017
#
#                                           clean_title
# 0                 the hunger games the hunger games 1
# 1   harry potter and the sorcerers stone harry pot...
# 2                               to kill a mockingbird
# 3                                    the great gatsby
# 4                              the fault in our stars
# 5                              the catcher in the rye
# 6                                                1984
# 7                    catching fire the hunger games 2
# 8                                     the kite runner
# 9   harry potter and the chamber of secrets harry ...
# 10  harry potter and the goblet of fire harry pott...
# 11  harry potter and the deathly hallows harry pot...
# 12  harry potter and the order of the phoenix harr...
# 13                      mockingjay the hunger games 3
# 14  harry potter and the halfblood prince harry po...
# 15                                     the book thief
# 16                              the girl on the train
# 17                                 the handmaids tale
# 18                        all the light we cannot see
# 19                                           pachinko

# %%
def make_clickable(val):
    # target _blank to open new window
    return '<a target="_blank" href="{}">{}</a>'.format(val, val)

#books_recs['url'] = books_recs['url'].apply(format_url)
books_recs.style.format({'url': make_clickable})
# Out:
# <style type="text/css">
# </style>
# <table id="T_9b883">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b883_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_9b883_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_9b883_level0_col2" class="col_heading level0 col2" >ratings</th>
#       <th id="T_9b883_level0_col3" class="col_heading level0 col3" >url</th>
#       <th id="T_9b883_level0_col4" class="col_heading level0 col4" >publication_year</th>
#       <th id="T_9b883_level0_col5" class="col_heading level0 col5" >clean_title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b883_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9b883_row0_col0" class="data row0 col0" >2767052</td>
#       <td id="T_9b883_row0_col1" class="data row0 col1" >The Hunger Games (The Hunger Games, #1)</td>
#       <td id="T_9b883_row0_col2" class="data row0 col2" >4899965</td>
#       <td id="T_9b883_row0_col3" class="data row0 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/2767052-the-hunger-games">https://www.goodreads.com/book/show/2767052-the-hunger-games</a></td>
#       <td id="T_9b883_row0_col4" class="data row0 col4" >2008</td>
#       <td id="T_9b883_row0_col5" class="data row0 col5" >the hunger games the hunger games 1</td>
#     </tr>
#     <tr>
#       <th id="T_9b883_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9b883_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_9b883_row1_col1" class="data row1 col1" >Harry Potter and the Sorcerer's Stone (Harry Potter, #1)</td>
#       <td id="T_9b883_row1_col2" class="data row1 col2" >4765497</td>
#       <td id="T_9b883_row1_col3" class="data row1 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/3.Harry_Potter_and_the_Sorcerer_s_Stone">https://www.goodreads.com/book/show/3.Harry_Potter_and_the_Sorcerer_s_Stone</a></td>
#       <td id="T_9b883_row1_col4" class="data row1 col4" >1997</td>
#       <td id="T_9b883_row1_col5" class="data row1 col5" >harry potter and the sorcerers stone harry potter 1</td>
#     </tr>
#     <tr>
#       <th id="T_9b883_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9b883_row2_col0" class="data row2 col0" >2657</td>
#       <td id="T_9b883_row2_col1" class="data row2 col1" >To Kill a Mockingbird</td>
#       <td id="T_9b883_row2_col2" class="data row2 col2" >3255518</td>
#       <td id="T_9b883_row2_col3" class="data row2 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/2657.To_Kill_a_Mockingbird">https://www.goodreads.com/book/show/2657.To_Kill_a_Mockingbird</a></td>
#       <td id="T_9b883_row2_col4" class="data row2 col4" >2006</td>
#       <td id="T_9b883_row2_col5" class="data row2 col5" >to kill a mockingbird</td>
#     </tr>
#     <tr>
#       <th id="T_9b883_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9b883_row3_col0" class="data row3 col0" >4671</td>
#       <td id="T_9b883_row3_col1" class="data row3 col1" >The Great Gatsby</td>
#       <td id="T_9b883_row3_col2" class="data row3 col2" >2758812</td>
#       <td id="T_9b883_row3_col3" class="data row3 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/4671.The_Great_Gatsby">https://www.goodreads.com/book/show/4671.The_Great_Gatsby</a></td>
#       <td id="T_9b883_row3_col4" class="data row3 col4" >2004</td>
#       <td id="T_9b883_row3_col5" class="data row3 col5" >the great gatsby</td>
#     </tr>
#     <tr>
#       <th id="T_9b883_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9b883_row4_col0" class="data row4 col0" >11870085</td>
#       <td id="T_9b883_row4_col1" class="data row4 col1" >The Fault in Our Stars</td>
#       <td id="T_9b883_row4_col2" class="data row4 col2" >2429317</td>
#       <td id="T_9b883_row4_col3" class="data row4 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/11870085-the-fault-in-our-stars">https://www.goodreads.com/book/show/11870085-the-fault-in-our-stars</a></td>
#       <td id="T_9b883_row4_col4" class="data row4 col4" >2012</td>
#       <td id="T_9b883_row4_col5" class="data row4 col5" >the fault in our stars</td>
#     </tr>
#     <tr>
#       <th id="T_9b883_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9b883_row5_col0" class="data row5 col0" >5107</td>
#       <td id="T_9b883_row5_col1" class="data row5 col1" >The Catcher in the Rye</td>
#       <td id="T_9b883_row5_col2" class="data row5 col2" >2086945</td>
#       <td id="T_9b883_row5_col3" class="data row5 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/5107.The_Catcher_in_the_Rye">https://www.goodreads.com/book/show/5107.The_Catcher_in_the_Rye</a></td>
#       <td id="T_9b883_row5_col4" class="data row5 col4" >2001</td>
#       <td id="T_9b883_row5_col5" class="data row5 col5" >the catcher in the rye</td>
#     </tr>
#     <tr>
#       <th id="T_9b883_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9b883_row6_col0" class="data row6 col0" >5470</td>
#       <td id="T_9b883_row6_col1" class="data row6 col1" >1984</td>
#       <td id="T_9b883_row6_col2" class="data row6 col2" >2023937</td>
#       <td id="T_9b883_row6_col3" class="data row6 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/5470.1984">https://www.goodreads.com/book/show/5470.1984</a></td>
#       <td id="T_9b883_row6_col4" class="data row6 col4" >1950</td>
#       <td id="T_9b883_row6_col5" class="data row6 col5" >1984</td>
#     </tr>
#     <tr>
#       <th id="T_9b883_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9b883_row7_col0" class="data row7 col0" >6148028</td>
#       <td id="T_9b883_row7_col1" class="data row7 col1" >Catching Fire (The Hunger Games, #2)</td>
#       <td id="T_9b883_row7_col2" class="data row7 col2" >1854746</td>
#       <td id="T_9b883_row7_col3" class="data row7 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/6148028-catching-fire">https://www.goodreads.com/book/show/6148028-catching-fire</a></td>
#       <td id="T_9b883_row7_col4" class="data row7 col4" >2009</td>
#       <td id="T_9b883_row7_col5" class="data row7 col5" >catching fire the hunger games 2</td>
#     </tr>
#     <tr>
#       <th id="T_9b883_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9b883_row8_col0" class="data row8 col0" >77203</td>
#       <td id="T_9b883_row8_col1" class="data row8 col1" >The Kite Runner</td>
#       <td id="T_9b883_row8_col2" class="data row8 col2" >1848782</td>
#       <td id="T_9b883_row8_col3" class="data row8 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/77203.The_Kite_Runner">https://www.goodreads.com/book/show/77203.The_Kite_Runner</a></td>
#       <td id="T_9b883_row8_col4" class="data row8 col4" >2004</td>
#       <td id="T_9b883_row8_col5" class="data row8 col5" >the kite runner</td>
#     </tr>
#     <tr>
#       <th id="T_9b883_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9b883_row9_col0" class="data row9 col0" >15881</td>
#       <td id="T_9b883_row9_col1" class="data row9 col1" >Harry Potter and the Chamber of Secrets (Harry Potter, #2)</td>
#       <td id="T_9b883_row9_col2" class="data row9 col2" >1821802</td>
#       <td id="T_9b883_row9_col3" class="data row9 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/15881.Harry_Potter_and_the_Chamber_of_Secrets">https://www.goodreads.com/book/show/15881.Harry_Potter_and_the_Chamber_of_Secrets</a></td>
#       <td id="T_9b883_row9_col4" class="data row9 col4" >1999</td>
#       <td id="T_9b883_row9_col5" class="data row9 col5" >harry potter and the chamber of secrets harry potter 2</td>
#     </tr>
#     <tr>
#       <th id="T_9b883_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9b883_row10_col0" class="data row10 col0" >6</td>
#       <td id="T_9b883_row10_col1" class="data row10 col1" >Harry Potter and the Goblet of Fire (Harry Potter, #4)</td>
#       <td id="T_9b883_row10_col2" class="data row10 col2" >1792561</td>
#       <td id="T_9
